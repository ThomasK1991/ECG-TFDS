# %%
import os
import pickle
import gzip
import wfdb

# %%
import wfdb
patient_id=9000
segment_id=0
start=100
length=1024

filename = './sample/p01001_s00'
rec = wfdb.rdrecord(filename, sampfrom=start, sampto=start+length)
ann = wfdb.rdann(filename, "atr", sampfrom=start, sampto=start+length, shift_samps=True)
wfdb.plot_wfdb(rec, ann, plot_sym=True, figsize=(15,4));

# %%
sample_id = 1001
path = './sample/'

# %%
data = wfdb.rdsamp('./sample/p01001_s00')

# %%
record = wfdb.rdrecord('./sample/p01001_s00')

# %%
filename = './sample.zip'
#filename_ecg = os.path.join(path, ("%05d" % sample_id) + "_batched.pkl.gz")

# %%
segments = pickle.load(gzip.open(filename))
#ecg = pickle.load(gzip.open(filename))
# Out:
# ---------------------------------------------------------------------------
# BadGzipFile                               Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 segments = pickle.load(gzip.open(filename))
#
# File /opt/homebrew/anaconda3/envs/cardiokit/lib/python3.10/gzip.py:321, in GzipFile.peek(self, n)
#     319     import errno
#     320     raise OSError(errno.EBADF, "peek() on write-only GzipFile object")
# --> 321 return self._buffer.peek(n)
#
# File /opt/homebrew/anaconda3/envs/cardiokit/lib/python3.10/_compression.py:68, in DecompressReader.readinto(self, b)
#      66 def readinto(self, b):
#      67     with memoryview(b) as view, view.cast("B") as byte_view:
# ---> 68         data = self.read(len(byte_view))
#      69         byte_view[:len(data)] = data
#      70     return len(data)
#
# File /opt/homebrew/anaconda3/envs/cardiokit/lib/python3.10/gzip.py:488, in _GzipReader.read(self, size)
#     484 if self._new_member:
# ...
